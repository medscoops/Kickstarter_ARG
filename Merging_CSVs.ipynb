# %%
import pandas as pd
d0 = pd.read_csv("data/data-2/Kickstarter000.csv")


d1 = pd.read_csv("data/data-2/Kickstarter001.csv")

# %%
d0.loc[:15].blurb
# Out:
# 0     2006 was almost 7 years ago.... Can you believ...
# 1     An adorable fantasy enamel pin series of princ...
# 2     Helping a community come together to set the s...
# 3     Every revolution starts from the bottom and we...
# 4     Learn to build 10+ Applications in this comple...
# 5     'Eclipse' - A 30mm hard enamel pin in jet blac...
# 6     Tao Of Maceo is a professionally printed journ...
# 7     Let's build and remix a new Personal Web Theme...
# 8     A limited edition, signed and numbered hand sc...
# 9     Play this hilarious, nonsensical card game for...
# 10    An homage to Mark Twain Manor, our former home...
# 11    A project giving voice to individuals living a...
# 12    Award Winning Footwear Designs | Crafted Using...
# 13    NAKEFIT: Hypoallergenic adhesive pad for walki...
# 14    OVERTHROW THE KING AND TAKE WHAT IS YOURS & Ki...
# 15    We are trying to reopen Gabutto Burger! Our Ja...
# Name: blurb, dtype: object

# %%
d0.shape
# Out:
# (3779, 37)

# %%
d1.head()
# Out:
#    backers_count                                              blurb  \
# 0             30  Experience tea and coffee as it should be in o...
# 1              0  Playing Roles Outside of Basic Education (P.R....
# 2            102   A pilot for a TV show called 'Merican Wasteland.
# 3             22  A film about suicide. The struggles of our mod...
# 4              2  Fusing the technical qualities and accuracy of...
#
#                                             category  \
# 0  {"id":350,"name":"Pottery","slug":"crafts/pott...
# 1  {"id":49,"name":"Periodicals","slug":"publishi...
# 2  {"id":11,"name":"Film & Video","slug":"film & ...
# 3  {"id":293,"name":"Drama","slug":"film & video/...
# 4  {"id":21,"name":"Digital Art","slug":"art/digi...
#
#    converted_pledged_amount country  created_at  \
# 0                      1547      GB  1515610761
# 1                         0      US  1426362805
# 2                      8101      US  1525106061
# ...

# %%
import pandas as pd
import glob
import os

# %%
# create file names
all_files = glob.glob(os.path.join('data/data-2', "*.csv"))
all_files.sort()
all_files
# Out:
# ['data/data-2/Kickstarter000.csv',
#  'data/data-2/Kickstarter001.csv',
#  'data/data-2/Kickstarter002.csv',
#  'data/data-2/Kickstarter003.csv',
#  'data/data-2/Kickstarter004.csv',
#  'data/data-2/Kickstarter005.csv',
#  'data/data-2/Kickstarter006.csv',
#  'data/data-2/Kickstarter007.csv',
#  'data/data-2/Kickstarter008.csv',
#  'data/data-2/Kickstarter009.csv',
#  'data/data-2/Kickstarter010.csv',
#  'data/data-2/Kickstarter011.csv',
#  'data/data-2/Kickstarter012.csv',
#  'data/data-2/Kickstarter013.csv',
#  'data/data-2/Kickstarter014.csv',
#  'data/data-2/Kickstarter015.csv',
#  'data/data-2/Kickstarter016.csv',
#  'data/data-2/Kickstarter017.csv',
#  'data/data-2/Kickstarter018.csv',
#  'data/data-2/Kickstarter019.csv',
#  'data/data-2/Kickstarter020.csv',
#  'data/data-2/Kickstarter021.csv',
#  'data/data-2/Kickstarter022.csv',
#  'data/data-2/Kickstarter023.csv',
#  'data/data-2/Kickstarter024.csv',
#  'data/data-2/Kickstarter025.csv',
#  'data/data-2/Kickstarter026.csv',
# ...

# %%
# merge files
merged_df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
merged_df.head()
# Out:
#    backers_count                                              blurb  \
# 0            315                                      Babalus Shoes
# 1             47  A colorful Dia de los Muertos themed oracle de...
# 2            271  Electra's long awaited, eclectic Debut Pop/Roc...
# 3              3  The Mist of Tribunal is a turn-based card game...
# 4              3  Livng with a brain impairment, what its like t...
#
#                                             category  \
# 0  {"id":266,"name":"Footwear","slug":"fashion/fo...
# 1  {"id":273,"name":"Playing Cards","slug":"games...
# 2  {"id":43,"name":"Rock","slug":"music/rock","po...
# 3  {"id":273,"name":"Playing Cards","slug":"games...
# 4  {"id":48,"name":"Nonfiction","slug":"publishin...
#
#    converted_pledged_amount country  created_at  \
# 0                     28645      US  1541459205
# 1                      1950      US  1501684093
# 2                     22404      US  1348987533
# ...

# %%
merged_df.shape
# Out:
# (209222, 37)

# %%
merged_df.tail()
# Out:
#         backers_count                                              blurb  \
# 209217             57  Steam Hollow is a Veteran owned Craft Brewery ...
# 209218             11  Over 250 healthy recipes free from ANY added S...
# 209219              0  Give your baby style and flair with "Gorgeous ...
# 209220             11  "The Lion & the Lyceum" is a children's book a...
# 209221             49  Award-winning aviation artist Philip E West's ...
#
#                                                  category  \
# 209217  {"id":307,"name":"Drinks","slug":"food/drinks"...
# 209218  {"id":306,"name":"Cookbooks","slug":"food/cook...
# 209219  {"id":264,"name":"Childrenswear","slug":"fashi...
# 209220  {"id":46,"name":"Children's Books","slug":"pub...
# 209221  {"id":23,"name":"Painting","slug":"art/paintin...
#
#         converted_pledged_amount country  created_at  \
# 209217                     10320      US  1487697908
# 209218                       305      AU  1450753265
# ...

# %%
# how-to convert a json string into a dict object
string = '{"id":266,"name":"Footwear","slug":"fashion/footwear","position":5,"parent_id":9,"color":16752598,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/fashion/footwear"}}}'
import json
json= json.loads(string)
print(json['id'])
print(type(json))
# Out:
# 266
# <class 'dict'>
